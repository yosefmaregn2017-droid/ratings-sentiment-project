# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Initialize sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Apply sentiment analysis to headlines
df['sentiment_score'] = df['headline'].apply(lambda x: sid.polarity_scores(x)['compound'])

# Classify sentiment
def label_sentiment(score):
    if score > 0.05:
        return "Positive"
    elif score < -0.05:
        return "Negative"
    else:
        return "Neutral"

df['sentiment_label'] = df['sentiment_score'].apply(label_sentiment)

# Preview results
df[['headline', 'sentiment_score', 'sentiment_label']].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 sid = SentimentIntensityAnalyzer()
#       6 # Apply sentiment analysis to headlines
# ----> 7 df['sentiment_score'] = df['headline'].apply(lambda x: sid.polarity_scores(x)['compound'])
#       9 # Classify sentiment
#      10 def label_sentiment(score):
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Load your CSV into df
file_path = r"../data/raw_analyst_ratings.csv"  # adjust filename if needed
df = pd.read_csv(file_path)

# Quick check
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       3 # Load your CSV into df
#       4 file_path = r"../data/raw_analyst_ratings.csv"  # adjust filename if needed
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
import matplotlib.pyplot as plt
import seaborn as sns

# Download VADER lexicon (if not already done)
nltk.download('vader_lexicon')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from nltk.sentiment.vader import SentimentIntensityAnalyzer
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
import matplotlib.pyplot as plt
import seaborn as sns

# Download VADER lexicon (if not already done)
nltk.download('vader_lexicon')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from nltk.sentiment.vader import SentimentIntensityAnalyzer
#
# ModuleNotFoundError: No module named 'pandas'
